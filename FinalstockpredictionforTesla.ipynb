# %% [markdown]
# **time series EDA**

# %%
# !pip install pandas-datareader
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pandas_datareader as pdr
import pandas as pd
from datetime import datetime

# %%
pip install --upgrade pandas_datareader
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install yfinance
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf

# Fetch the data
tsla_data = yf.download('TSLA', start='2017-01-01', end='2024-07-17')

# Display the data
print(tsla_data)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-01-03   14.324000   14.688667   14.064000   14.466000   14.466000
# 2017-01-04   14.316667   15.200000   14.287333   15.132667   15.132667
# 2017-01-05   15.094667   15.165333   14.796667   15.116667   15.116667
# 2017-01-06   15.128667   15.354000   15.030000   15.267333   15.267333
# 2017-01-09   15.264667   15.461333   15.200000   15.418667   15.418667
# ...                ...         ...         ...         ...         ...
# 2024-07-10  262.799988  267.589996  257.859985  263.260010  263.260010
# 2024-07-11  263.299988  271.000000  239.649994  241.029999  241.029999
# 2024-07-12  235.800003  251.839996  233.089996  248.229996  248.229996
# 2024-07-15  255.970001  265.600006  251.729996  252.639999  252.639999
# 2024-07-16  255.309998  258.619995  245.800003  256.559998  256.559998
#
#                Volume
# Date
# ...

# %%
type(tsla_data)
# Out:
# pandas.core.frame.DataFrame

# %%
tsla_data.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2017-01-03  14.324000  14.688667  14.064000  14.466000  14.466000   88849500
# 2017-01-04  14.316667  15.200000  14.287333  15.132667  15.132667  168202500
# 2017-01-05  15.094667  15.165333  14.796667  15.116667  15.116667   88675500
# 2017-01-06  15.128667  15.354000  15.030000  15.267333  15.267333   82918500
# 2017-01-09  15.264667  15.461333  15.200000  15.418667  15.418667   59692500

# %%
tsla_data.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-07-10  262.799988  267.589996  257.859985  263.260010  263.260010
# 2024-07-11  263.299988  271.000000  239.649994  241.029999  241.029999
# 2024-07-12  235.800003  251.839996  233.089996  248.229996  248.229996
# 2024-07-15  255.970001  265.600006  251.729996  252.639999  252.639999
# 2024-07-16  255.309998  258.619995  245.800003  256.559998  256.559998
#
#                Volume
# Date
# 2024-07-10  128519400
# 2024-07-11  221707300
# 2024-07-12  155955800
# 2024-07-15  146912900
# 2024-07-16  126332500

# %%
tsla_data.plot(figsize=(15,6))
plt.show()

# %%
tsla_data['High'].plot(figsize=(12,4))
# Out:
# <Axes: xlabel='Date'>

# %%
tsla_data['Low'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
## x limit and y limit
tsla_data['High'].plot(xlim=['2023-01-01','2024-01-01'],figsize=(12,4))
# Out:
# <Axes: xlabel='Date'>

# %%
## x limit and y limit
tsla_data['High'].plot(xlim=['2019-01-01','2021-01-01'],ylim=[0,900],figsize=(12,4))
# Out:
# <Axes: xlabel='Date'>

# %%
## x limit and y limit and colouring and line space
tsla_data['High'].plot(xlim=['2023-01-01','2024-01-01'],ylim=[0,900],figsize=(12,4),c='green',ls='--')
# Out:
# <Axes: xlabel='Date'>

# %%
##get all the dates from the data
tsla_data.index
# Out:
# DatetimeIndex(['2017-01-03', '2017-01-04', '2017-01-05', '2017-01-06',
#                '2017-01-09', '2017-01-10', '2017-01-11', '2017-01-12',
#                '2017-01-13', '2017-01-17',
#                ...
#                '2024-07-02', '2024-07-03', '2024-07-05', '2024-07-08',
#                '2024-07-09', '2024-07-10', '2024-07-11', '2024-07-12',
#                '2024-07-15', '2024-07-16'],
#               dtype='datetime64[ns]', name='Date', length=1895, freq=None)

# %%
##how we reads those specific dates
tsla_data.loc['2019-01-01':'2021-01-01']
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-01-02   20.406668   21.008667   19.920000   20.674667   20.674667
# 2019-01-03   20.466667   20.626667   19.825333   20.024000   20.024000
# 2019-01-04   20.400000   21.200001   20.181999   21.179333   21.179333
# 2019-01-07   21.448000   22.449333   21.183332   22.330667   22.330667
# 2019-01-08   22.797333   22.934000   21.801332   22.356667   22.356667
# ...                ...         ...         ...         ...         ...
# 2020-12-24  214.330002  222.029999  213.666672  220.589996  220.589996
# 2020-12-28  224.836670  227.133331  220.266663  221.229996  221.229996
# 2020-12-29  220.333328  223.300003  218.333328  221.996674  221.996674
# 2020-12-30  224.000000  232.199997  222.786667  231.593338  231.593338
# 2020-12-31  233.330002  239.573334  230.373337  235.223328  235.223328
#
#                Volume
# Date
# 2019-01-02  174879000
# 2019-01-03  104478000
# 2019-01-04  110911500
# ...

# %%
index=tsla_data.loc['2019-01-01':'2021-01-01'].index
index
# Out:
# DatetimeIndex(['2019-01-02', '2019-01-03', '2019-01-04', '2019-01-07',
#                '2019-01-08', '2019-01-09', '2019-01-10', '2019-01-11',
#                '2019-01-14', '2019-01-15',
#                ...
#                '2020-12-17', '2020-12-18', '2020-12-21', '2020-12-22',
#                '2020-12-23', '2020-12-24', '2020-12-28', '2020-12-29',
#                '2020-12-30', '2020-12-31'],
#               dtype='datetime64[ns]', name='Date', length=505, freq=None)

# %%
##how to get open data of a stock during a time farme
share_openPrice=tsla_data.loc['2019-01-01':'2021-01-01']['Open']

# %%
share_openPrice
# Out:
# Date
# 2019-01-02     20.406668
# 2019-01-03     20.466667
# 2019-01-04     20.400000
# 2019-01-07     21.448000
# 2019-01-08     22.797333
#                  ...
# 2020-12-24    214.330002
# 2020-12-28    224.836670
# 2020-12-29    220.333328
# 2020-12-30    224.000000
# 2020-12-31    233.330002
# Name: Open, Length: 505, dtype: float64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
figure,axis=plt.subplots()
axis.plot(index,share_openPrice)
## Preventing overlapping
figure.autofmt_xdate()
plt.tight_layout()
plt.show()

# %%
##datetime index
tsla_data=tsla_data.reset_index()

# %%
tsla_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1895 entries, 0 to 1894
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1895 non-null   datetime64[ns]
#  1   Open       1895 non-null   float64
#  2   High       1895 non-null   float64
#  3   Low        1895 non-null   float64
#  4   Close      1895 non-null   float64
#  5   Adj Close  1895 non-null   float64
#  6   Volume     1895 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 103.8 KB

# %%
pd.to_datetime(tsla_data['Date'])
# Out:
# 0      2017-01-03
# 1      2017-01-04
# 2      2017-01-05
# 3      2017-01-06
# 4      2017-01-09
#           ...
# 1890   2024-07-10
# 1891   2024-07-11
# 1892   2024-07-12
# 1893   2024-07-15
# 1894   2024-07-16
# Name: Date, Length: 1895, dtype: datetime64[ns]

# %%
tsla_data=tsla_data.set_index('Date',drop=True)

# %%
tsla_data
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-01-03   14.324000   14.688667   14.064000   14.466000   14.466000
# 2017-01-04   14.316667   15.200000   14.287333   15.132667   15.132667
# 2017-01-05   15.094667   15.165333   14.796667   15.116667   15.116667
# 2017-01-06   15.128667   15.354000   15.030000   15.267333   15.267333
# 2017-01-09   15.264667   15.461333   15.200000   15.418667   15.418667
# ...                ...         ...         ...         ...         ...
# 2024-07-10  262.799988  267.589996  257.859985  263.260010  263.260010
# 2024-07-11  263.299988  271.000000  239.649994  241.029999  241.029999
# 2024-07-12  235.800003  251.839996  233.089996  248.229996  248.229996
# 2024-07-15  255.970001  265.600006  251.729996  252.639999  252.639999
# 2024-07-16  255.309998  258.619995  245.800003  256.559998  256.559998
#
#                Volume
# Date
# 2017-01-03   88849500
# 2017-01-04  168202500
# 2017-01-05   88675500
# ...

# %%
##datetime
from datetime import datetime

# %%
datetime(2022,8,21)
# Out:
# datetime.datetime(2022, 8, 21, 0, 0)

# %%
datetime.now()
# Out:
# datetime.datetime(2024, 7, 26, 12, 20, 56, 499108)

# %%
def add_num(num1,num2):
    return num1+num2

# %%
start_time=datetime.now()
num1=20
num2=90
for i in [1,2,3,4,5]:
    add_num(num1,num2)
end_time=datetime.now()
print(end_time-start_time)
# Out:
# 0:00:00

# %%
date=datetime(2024,7,19)

# %%
date
# Out:
# datetime.datetime(2024, 7, 19, 0, 0)

# %%
date.date()
# Out:
# datetime.date(2024, 7, 19)

# %%
date.day
# Out:
# 19

# %%
date.month
# Out:
# 7

# %%
date.weekday()
# Out:
# 4

# %%
date.year
# Out:
# 2024

# %%
date.hour
# Out:
# 0

# %% [markdown]
# ##time resampling

# %%
tsla_data.resample(rule='A').min()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-12-31   14.316667   14.688667   14.064000   14.466000   14.466000
# 2018-12-31   16.851999   17.355333   16.306000   16.704000   16.704000
# 2019-12-31   12.073333   12.445333   11.799333   11.931333   11.931333
# 2020-12-31   24.980000   26.990667   23.367332   24.081333   24.081333
# 2021-12-31  184.183334  188.736664  179.830002  187.666672  187.666672
# 2022-12-31  110.349998  116.269997  108.239998  109.099998  109.099998
# 2023-12-31  103.000000  111.750000  101.809998  108.099998  108.099998
# 2024-12-31  140.559998  144.440002  138.800003  142.050003  142.050003
#
#               Volume
# Date
# 2017-12-31  32800500
# 2018-12-31  46210500
# 2019-12-31  36984000
# 2020-12-31  52073100
# 2021-12-31  29401800
# 2022-12-31  41864700
# 2023-12-31  65125200
# 2024-12-31  50869700

# %%
tsla_data.resample(rule='A').max()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-12-31   25.779333   25.974001   25.290001   25.666668   25.666668
# 2018-12-31   25.000000   25.830667   24.474667   25.304667   25.304667
# 2019-12-31   29.000000   29.020666   28.423332   28.729334   28.729334
# 2020-12-31  233.330002  239.573334  230.373337  235.223328  235.223328
# 2021-12-31  411.470001  414.496674  405.666656  409.970001  409.970001
# 2022-12-31  396.516663  402.666656  378.679993  399.926666  399.926666
# 2023-12-31  296.040009  299.290009  289.519989  293.339996  293.339996
# 2024-12-31  263.299988  271.000000  257.859985  263.260010  263.260010
#
#                Volume
# Date
# 2017-12-31  296871000
# 2018-12-31  504745500
# 2019-12-31  450091500
# 2020-12-31  914082000
# 2021-12-31  268189500
# 2022-12-31  221923300
# 2023-12-31  306590600
# 2024-12-31  243869700

# %%
## year end frequency
tsla_data.resample(rule='A').max()['Open'].plot()
plt.show()

# %%
##quarterly start frequency
tsla_data.resample(rule='QS').max()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-01-01   18.687332   19.159332   18.573999   18.732000   18.732000
# 2017-04-01   25.779333   25.799334   25.290001   25.563334   25.563334
# 2017-07-01   25.350000   25.974001   25.178667   25.666668   25.666668
# 2017-10-01   23.798668   24.200001   23.608667   23.976667   23.976667
# 2018-01-01   24.000000   24.033333   23.490667   23.827999   23.827999
# 2018-04-01   24.344000   24.915333   23.633333   24.722000   24.722000
# 2018-07-01   24.606001   25.830667   24.474667   25.304667   25.304667
# 2018-10-01   25.000000   25.299334   24.450001   25.119333   25.119333
# 2019-01-01   23.080667   23.466667   22.943333   23.153999   23.153999
# 2019-04-01   19.219999   19.744667   19.144667   19.454000   19.454000
# 2019-07-01   17.278000   17.738001   17.210667   17.658667   17.658667
# 2019-10-01   29.000000   29.020666   28.423332   28.729334   28.729334
# ...

# %%
tsla_data.resample(rule='QS').max()['High'].plot()
plt.show()

# %%
##business end frequency
tsla_data.resample(rule='BA').max()['High'].plot()
plt.show()

# %%
tsla_data.resample(rule='BA').max()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-12-29   25.779333   25.974001   25.290001   25.666668   25.666668
# 2018-12-31   25.000000   25.830667   24.474667   25.304667   25.304667
# 2019-12-31   29.000000   29.020666   28.423332   28.729334   28.729334
# 2020-12-31  233.330002  239.573334  230.373337  235.223328  235.223328
# 2021-12-31  411.470001  414.496674  405.666656  409.970001  409.970001
# 2022-12-30  396.516663  402.666656  378.679993  399.926666  399.926666
# 2023-12-29  296.040009  299.290009  289.519989  293.339996  293.339996
# 2024-12-31  263.299988  271.000000  257.859985  263.260010  263.260010
#
#                Volume
# Date
# 2017-12-29  296871000
# 2018-12-31  504745500
# 2019-12-31  450091500
# 2020-12-31  914082000
# 2021-12-31  268189500
# 2022-12-30  221923300
# 2023-12-29  306590600
# 2024-12-31  243869700

# %%
##bar plotting 
tsla_data['Open'].resample(rule='BA').mean().plot(kind='bar')
plt.show()

# %%
##monthly data
tsla_data['Open'].resample(rule='M').max().plot(kind='bar',figsize=(15,6))
plt.show()

# %%
##roolling 
tsla_data['High'].rolling(10).mean().head(20)
# Out:
# Date
# 2017-01-03          NaN
# 2017-01-04          NaN
# 2017-01-05          NaN
# 2017-01-06          NaN
# 2017-01-09          NaN
# 2017-01-10          NaN
# 2017-01-11          NaN
# 2017-01-12          NaN
# 2017-01-13          NaN
# 2017-01-17    15.390200
# 2017-01-18    15.519400
# 2017-01-19    15.657267
# 2017-01-20    15.780733
# 2017-01-23    15.917933
# 2017-01-24    16.070467
# 2017-01-25    16.246867
# 2017-01-26    16.418600
# 2017-01-27    16.567267
# 2017-01-30    16.683533
# 2017-01-31    16.789734
# Name: High, dtype: float64

# %%
##rolling of 30 days data 
tsla_data['open:30 days rolling']=tsla_data['Open'].rolling(30).mean()

# %%
tsla_data.head(31)
# Out:
#                  Open       High        Low      Close  Adj Close     Volume  \
# Date
# 2017-01-03  14.324000  14.688667  14.064000  14.466000  14.466000   88849500
# 2017-01-04  14.316667  15.200000  14.287333  15.132667  15.132667  168202500
# 2017-01-05  15.094667  15.165333  14.796667  15.116667  15.116667   88675500
# 2017-01-06  15.128667  15.354000  15.030000  15.267333  15.267333   82918500
# 2017-01-09  15.264667  15.461333  15.200000  15.418667  15.418667   59692500
# 2017-01-10  15.466667  15.466667  15.126000  15.324667  15.324667   54900000
# 2017-01-11  15.271333  15.332000  15.112000  15.315333  15.315333   54762000
# 2017-01-12  15.270667  15.380000  15.038667  15.306000  15.306000   56853000
# 2017-01-13  15.333333  15.856667  15.306000  15.850000  15.850000   91395000
# 2017-01-17  15.780000  15.997333  15.624667  15.705333  15.705333   69262500
# 2017-01-18  15.776667  15.980667  15.705333  15.890667  15.890667   56535000
# ...

# %%
tsla_data[['Open','open:30 days rolling']].plot(figsize=(12,4))
plt.show()

# %%
##upward and downward trend,stationary data,cyclic data,

# %%
#sim[ple moving average
tsla_data['Open'].plot(figsize=(14,5))
plt.show()

# %%
##simple moving average
tsla_data['Open:10 days rolling']=tsla_data['Open'].rolling(window=10,min_periods=1).mean()

# %%
tsla_data[['Open','Open:10 days rolling']].plot(xlim=['2020-01-01','2021-01-01'],figsize=(15,6))
plt.show()

# %%
##disadvantage of simple moving average

# %%
##cumulative moving average
tsla_data['Open'].expanding().mean().plot(figsize=(10,5))
plt.show()

# %%
##exponential moving average(EMA)
#lets smoothing factror is 0.1
tsla_data['EMA_0.1']=tsla_data['Open'].ewm(alpha=0.1,adjust=False).mean()

# %%
tsla_data[['Open','EMA_0.1']].plot(xlim=['2020-01-01','2021-01-01'],figsize=(15,6))
plt.show()

# %%
tsla_data['EMA_0.3']=tsla_data['Open'].ewm(alpha=0.3,adjust=False).mean()

# %%
tsla_data[['Open','EMA_0.3']].plot(xlim=['2020-01-01','2021-01-01'],figsize=(15,6))
plt.show()

# %%
tsla_data[['Open','EMA_0.1','EMA_0.3']].plot(xlim=['2020-01-01','2021-01-01'],figsize=(15,6))
plt.show()

# %%
tsla_data['EMA_5days']=tsla_data['Open'].ewm(span=5).mean()

# %%
tsla_data[['Open','EMA_0.1','EMA_5days']].plot(figsize=(15,6))
plt.show()

# %%
tsla_data1=tsla_data.reset_index()['Close']

# %%
tsla_data1
# Out:
# 0        14.466000
# 1        15.132667
# 2        15.116667
# 3        15.267333
# 4        15.418667
#            ...
# 1890    263.260010
# 1891    241.029999
# 1892    248.229996
# 1893    252.639999
# 1894    256.559998
# Name: Close, Length: 1895, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.plot(tsla_data1)
plt.show()

# %%
import numpy as np

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1))
tsla_data1=scaler.fit_transform(np.array(tsla_data1).reshape(-1,1))

# %%
print(tsla_data1)
# Out:
# [[0.00636789]
#  [0.00804277]
#  [0.00800257]
#  ...
#  [0.59365756]
#  [0.60473689]
#  [0.61458518]]

# %%
##splitting dataset into train and test split
trainning_size=int(len(tsla_data1)*0.65)
test_size=len(tsla_data1)-trainning_size
train_data,test_data=tsla_data1[0:trainning_size,:],tsla_data1[trainning_size:len(tsla_data1),:1]

# %%
trainning_size,test_size
# Out:
# (1231, 664)

# %%
len(train_data)
# Out:
# 1231

# %%
len(test_data)
# Out:
# 664

# %%
train_data
# Out:
# array([[0.00636789],
#        [0.00804277],
#        [0.00800257],
#        ...,
#        [0.88200474],
#        [0.88817667],
#        [0.9222437 ]])

# %%
test_data
# Out:
# array([[0.93883338],
#        [0.8987703 ],
#        [0.90460725],
#        [0.87606735],
#        [0.92218513],
#        [0.92869203],
#        [0.88702102],
#        [0.87831163],
#        [0.82000074],
#        [0.8150096 ],
#        [0.85080179],
#        [0.86521412],
#        [0.81064655],
#        [0.82172588],
#        [0.77933465],
#        [0.77271888],
#        [0.78735731],
#        [0.74626417],
#        [0.75099569],
#        [0.72367009],
#        [0.75598683],
#        [0.81489237],
#        [0.86357269],
#        [0.88613334],
#        [0.88155254],
#        [0.87964316],
#        [0.86636976],
#        [0.85501411],
#        [0.97476794],
#        [0.93273682],
#        [0.88125944],
#        [0.86164659],
#        [0.83004165],
#        [0.85613625],
#        [0.86139534],
#        [0.89641707],
#        [0.83389386],
#        [0.84900963],
#        [0.83301453],
#        [0.8038214 ],
#        [0.80434061],
#        [0.7604839 ],
#        [0.74884349],
# ...

# %%
#data preprocessing
#convert an array of values into a dataset matrix
import numpy
def create_dataset(dataset,time_step=1):
    dataX ,dataY=[], []
    for  i in range(len(dataset)-time_step-1):
        a=dataset[i:(i+time_step),0]
        dataX.append(a)
        dataY.append(dataset[i+time_step,0])
    return numpy.array(dataX),numpy.array(dataY)

# %%
#reshape into x=t,t+1,t+2,t+3and y=t+4
time_step=100
X_train,Y_train=create_dataset(train_data,time_step)
X_test,Y_test=create_dataset(test_data,time_step)

# %%
print(X_train)
# Out:
# [[0.00636789 0.00804277 0.00800257 ... 0.02091757 0.02198279 0.02308989]
#  [0.00804277 0.00800257 0.0083811  ... 0.02198279 0.02308989 0.02448171]
#  [0.00800257 0.0083811  0.0087613  ... 0.02308989 0.02448171 0.02614989]
#  ...
#  [0.53267521 0.54678607 0.54012005 ... 0.86065003 0.83545148 0.81867757]
#  [0.54678607 0.54012005 0.53923237 ... 0.83545148 0.81867757 0.85329732]
#  [0.54012005 0.53923237 0.53774171 ... 0.81867757 0.85329732 0.88200474]]

# %%
print(Y_train)
# Out:
# [0.02448171 0.02614989 0.02713974 ... 0.85329732 0.88200474 0.88817667]

# %%
print(X_test.shape),print(Y_test.shape)
# Out:
# (563, 100)
# (563,)
# (None, None)

# %%
print(X_train.shape),print(Y_train.shape)
# Out:
# (1130, 100)
# (1130,)
# (None, None)

# %%
#reshape input to be[samples,time steps,features]which is required for LSTM
X_train=X_train.reshape(X_train.shape[0],X_train.shape[1],1)
X_test=X_test.reshape(X_test.shape[0],X_train.shape[1],1)

# %%
#create the stacked lstm model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

# %%
#stacked lstm model
model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(100,1)))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')
# Out:
# C:\Users\Rajib Guin\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 100, 50)             │          10,400 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 100, 50)             │          20,200 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_2 (LSTM)                        │ (None, 50)                  │          20,200 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │              51 │
# ...

# %%
model.fit(X_train,Y_train,validation_data=(X_test,Y_test),epochs=100,batch_size=64,verbose=1)
# Out:
# Epoch 1/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 14s 265ms/step - loss: 0.0485 - val_loss: 0.0059
# Epoch 2/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 159ms/step - loss: 0.0028 - val_loss: 0.0068
# Epoch 3/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 167ms/step - loss: 0.0017 - val_loss: 0.0069
# Epoch 4/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 167ms/step - loss: 0.0016 - val_loss: 0.0047
# Epoch 5/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 160ms/step - loss: 0.0017 - val_loss: 0.0064
# Epoch 6/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 170ms/step - loss: 0.0018 - val_loss: 0.0041
# Epoch 7/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 174ms/step - loss: 0.0013 - val_loss: 0.0031
# Epoch 8/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 170ms/step - loss: 0.0012 - val_loss: 0.0032
# Epoch 9/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 172ms/step - loss: 0.0012 - val_loss: 0.0028
# Epoch 10/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 172ms/step - loss: 8.8703e-04 - val_loss: 0.0035
# Epoch 11/100
# ...

# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.17.0'

# %%
##lets do the prediction and check the performance metrics
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)
# Out:
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step

# %%
##transform back to original form
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)

# %%
##calculate the rmse performance metrics
import math
from sklearn.metrics import mean_squared_error
math.sqrt(mean_squared_error(Y_train,train_predict))
# Out:
# 122.19113341583984

# %%
 ##test data rmse
math.sqrt(mean_squared_error(Y_test,test_predict))
# Out:
# 219.23442313469423

# %%
#plotting
#shift train prediction for plotting
look_back=100
trainPredictPlot=numpy.empty_like(tsla_data1)
trainPredictPlot[:, :]=np.nan
trainPredictPlot[look_back:len(train_predict)+look_back,:]=train_predict
#shift test prediction for plotting
testPredictPlot=numpy.empty_like(tsla_data1)
testPredictPlot[:, :]=numpy.nan
testPredictPlot[len(train_predict)+(look_back*2)+1:len(tsla_data1)-1,:]=test_predict
#plot baseline and prediction
plt.plot(scaler.inverse_transform(tsla_data1))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()

# %%
len(test_data)
# Out:
# 664

# %%
X_input=test_data[564:].reshape(1,-1)
X_input.shape
# Out:
# (1, 100)

# %%
temp_input=list(X_input)
temp_input=temp_input[0].tolist()

# %%
temp_input
# Out:
# [0.49123034904479324,
#  0.4593490183062403,
#  0.45384703416753797,
#  0.43611007011113384,
#  0.43495438663081376,
#  0.433572603665738,
#  0.439300687289196,
#  0.4235986952654754,
#  0.4370647251584158,
#  0.4348036536409767,
#  0.4399287669701448,
#  0.43307014758796725,
#  0.42372431886865347,
#  0.3795075323308211,
#  0.3847582692631673,
#  0.37840210595876056,
#  0.3736789344908441,
#  0.3562936935223736,
#  0.37247303223720596,
#  0.38282377311206134,
#  0.3765932334108326,
#  0.37277449821688013,
#  0.373528201501007,
#  0.3750104603476603,
#  0.39726960577388426,
#  0.4016159064322665,
#  0.3949833865348446,
#  0.39345087057993183,
#  0.4023445003297344,
#  0.3920439782281971,
#  0.38794892477617093,
#  0.3883760143590232,
#  0.4068164245912947,
#  0.41442874725759915,
#  0.42259378310993384,
#  0.4445263148348832,
#  0.43673814979208264,
#  0.42952776898702993,
#  0.43347212778416044,
#  0.4553292930141913,
#  0.47540273341789463,
#  0.4823618286816497,
# ...

# %%
#demonstrate prediction for 10 days
lst_output = []
n_steps = 100
i = 0
while i < 30:
    if len(temp_input) > n_steps:
        X_input = np.array(temp_input[-n_steps:])
        print("{} day input {}".format(i, X_input))
        X_input = X_input.reshape((1, n_steps, 1))
        yhat = model.predict(X_input, verbose=0)
        print("{} day output {}".format(i, yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input = temp_input[1:]
        lst_output.extend(yhat.tolist())
        i += 1
    else:
        # In case temp_input has fewer than n_steps elements
        padding = n_steps - len(temp_input)
        X_input = np.array([0]*padding + temp_input)  # Pad with zeros or other appropriate value
        X_input = X_input.reshape((1, n_steps, 1))
        yhat = model.predict(X_input, verbose=0)
        print(yhat[0])
        temp_input.extend(yhat[0].tolist())
        print(len(temp_input))
        lst_output.extend(yhat.tolist())
        i += 1

print(lst_output)
# Out:
# [0.5986042]
# 101
# 1 day input [0.45231452 0.47098103 0.4718101  0.47761355 0.47721161 0.47912095
#  0.44269233 0.42410119 0.41354942 0.41885041 0.41053465 0.4166396
#  0.41606174 0.39581246 0.37827648 0.38096468 0.40666569 0.40043515
#  0.41133861 0.40420363 0.3992041  0.40372628 0.41638835 0.42181497
#  0.41166518 0.41023318 0.38865237 0.39304893 0.39990755 0.38430603
#  0.40460557 0.41440364 0.40154054 0.40867555 0.39975682 0.37571391
#  0.36473509 0.36056463 0.34669662 0.33946117 0.32689957 0.33350694
#  0.37734694 0.39757107 0.39282279 0.45754015 0.43048246 0.42221695
#  0.42226717 0.42523173 0.43420068 0.41674008 0.40897702 0.40206814
#  0.39327503 0.40186715 0.41608689 0.40714304 0.40927849 0.41586079
#  0.40955484 0.43882338 0.42251842 0.40651496 0.42033271 0.41407702
#  0.41267013 0.41920214 0.41741841 0.41292134 0.40910264 0.40968047
#  0.41706669 0.41591101 0.40664054 0.39877701 0.41543366 0.42844749
#  0.41724253 0.44093372 0.43445193 0.42618642 0.42980413 0.42872385
# ...

# %%
day_new=np.arange(1,101)
day_pred=np.arange(101,131)

# %%
import matplotlib.pyplot as plt

# %%
len(tsla_data1)
# Out:
# 1895

# %%
plt.plot(day_new,scaler.inverse_transform(tsla_data1[1795:]))
plt.plot(day_pred,scaler.inverse_transform(lst_output))
plt.show()

# %%
df3=tsla_data1.tolist()
df3.extend(lst_output)
plt.plot(df3[1800:])
plt.show()

# %%
df3=scaler.inverse_transform(df3).tolist()

# %%
plt.plot(df3)
plt.show()
